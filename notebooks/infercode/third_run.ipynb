# %% [markdown]
# 第3回実行
#
# epoc 60で間に合うかどうか

# %%
from argparse import ArgumentParser

from omegaconf import DictConfig, OmegaConf
from pytorch_lightning import Trainer

from code2seq.data.path_context_data_module import PathContextDataModule
from code2seq.model import Code2Seq
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/akihito/Desktop/research/code2seq_pytorch/third_run.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell:/Users/akihito/Desktop/research/code2seq_pytorch/third_run.ipynb#ch0000001?line=3'>4</a> from pytorch_lightning import Trainer
#       <a href='vscode-notebook-cell:/Users/akihito/Desktop/research/code2seq_pytorch/third_run.ipynb#ch0000001?line=5'>6</a> from code2seq.data.path_context_data_module import PathContextDataModule
# ----> <a href='vscode-notebook-cell:/Users/akihito/Desktop/research/code2seq_pytorch/third_run.ipynb#ch0000001?line=6'>7</a> from code2seq.model import Code2Seq
#
# File ~/Desktop/research/code2seq_pytorch/code2seq/model/__init__.py:2, in <module>
#       <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/__init__.py?line=0'>1</a> from .code2class import Code2Class
# ----> <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/__init__.py?line=1'>2</a> from .code2seq import Code2Seq
#       <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/__init__.py?line=2'>3</a> from .typed_code2seq import TypedCode2Seq
#       <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/__init__.py?line=4'>5</a> __all__ = ["Code2Class", "Code2Seq", "TypedCode2Seq"]
#
# File ~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py:20, in <module>
#      <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py?line=17'>18</a> from code2seq.model.modules import PathEncoder
#      <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py?line=18'>19</a> from code2seq.utils.optimization import configure_optimizers_alon
# ---> <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py?line=19'>20</a> from code2seq.model.metrics import Perfect, Leivensitein, BLEU
#      <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py?line=21'>22</a> class Code2Seq(LightningModule):
#      <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py?line=22'>23</a>     def __init__(
#      <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py?line=23'>24</a>         self,
#      <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py?line=24'>25</a>         model_config: DictConfig,
#    (...)
#      <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py?line=27'>28</a>         teacher_forcing: float = 0.0,
#      <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/code2seq.py?line=28'>29</a>     ):
#
# File ~/Desktop/research/code2seq_pytorch/code2seq/model/metrics.py:2, in <module>
#       <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/metrics.py?line=0'>1</a> from torchmetrics import Metric
# ----> <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/metrics.py?line=1'>2</a> from nltk import bleu_score
#       <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/metrics.py?line=2'>3</a> import torch
#       <a href='file:///~/Desktop/research/code2seq_pytorch/code2seq/model/metrics.py?line=3'>4</a> import numpy as np
#
# ModuleNotFoundError: No module named 'nltk'

# %%
# configファイルの読み込み
filepath = "config/code2seq-codereview-full-v3.yaml"
#filepath = "config/code2seq-java-small.yaml"
#filepath = "config/code2seq-codereview-full.yaml"
config = OmegaConf.load(filepath)

# %%
# data loaderの読み込み
data_module = PathContextDataModule(config.data_folder, config.data)

data_module

# %%
# Define model
model = Code2Seq(
    config.model,
    config.optimizer,
    data_module.vocabulary,
    config.train.teacher_forcing
)

# %%
# Define hyper parameters
trainer = Trainer(max_epochs=config.train.n_epochs)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
# Train model
result = trainer.fit(model, datamodule=data_module)
# Out:
# Dataset is already downloaded
#   | Name               | Type                     | Params
# ----------------------------------------------------------------
# 0 | _Code2Seq__metrics | MetricCollection         | 0
# 1 | _encoder           | PathEncoder              | 472 K
# 2 | _decoder           | Decoder                  | 384 K
# 3 | _Code2Seq__loss    | SequenceCrossEntropyLoss | 0
# ----------------------------------------------------------------
# 857 K     Trainable params
# 0         Non-trainable params
# 857 K     Total params
# 3.428     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
#   0%|          | 0/1542 [00:00<?, ?it/s]
# /Users/akihito/.local/share/virtualenvs/code2seq_pytorch-Ict_rOmF/lib/python3.8/site-packages/pytorch_lightning/trainer/data_loading.py:110: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
#   0%|          | 0/12117 [00:00<?, ?it/s]
# /Users/akihito/.local/share/virtualenvs/code2seq_pytorch-Ict_rOmF/lib/python3.8/site-packages/pytorch_lightning/trainer/data_loading.py:110: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /Users/akihito/.local/share/virtualenvs/code2seq_pytorch-Ict_rOmF/lib/python3.8/site-packages/pytorch_lightning/trainer/data_loading.py:394: UserWarning: The number of training samples (24) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
result = trainer.test( datamodule=data_module,ckpt_path="best")
# Out:
# Restoring states from the checkpoint path at /Users/akihito/Desktop/code2seq_pytorch/lightning_logs/version_54/checkpoints/epoch=29-step=719.ckpt
# Loaded model weights from checkpoint at /Users/akihito/Desktop/code2seq_pytorch/lightning_logs/version_54/checkpoints/epoch=29-step=719.ckpt
#   0%|          | 0/1506 [00:00<?, ?it/s]
# /Users/akihito/.local/share/virtualenvs/code2seq_pytorch-Ict_rOmF/lib/python3.8/site-packages/pytorch_lightning/trainer/data_loading.py:110: UserWarning: The dataloader, test_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test/acc': 0.013832459226250648,
#  'test/bleu': 0.0,
#  'test/chrf': 0.9681941270828247,
#  'test/f1': 0.419393926858902,
#  'test/lei': 0.9847277402877808,
#  'test/loss': 1379.4676513671875,
#  'test/perfect': 0.0,
#  'test/precision': 0.38844621181488037,
#  'test/recall': 0.45569974184036255}
# --------------------------------------------------------------------------------

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs
# Out:
# Reusing TensorBoard on port 6006 (pid 15407), started 13:24:31 ago. (Use '!kill 15407' to kill it.)
#       <iframe id="tensorboard-frame-11fda48f00980cf3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-11fda48f00980cf3");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Train model
from pytorch_lightning.callbacks import ModelCheckpoint
checkpoint_callback = ModelCheckpoint(dirpath='lightning_logs/version_54/')

# %%
trainer = Trainer(callbacks=[checkpoint_callback],max_epochs=60)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
model
result = trainer.fit(model, datamodule=data_module)
# Out:
#   | Name               | Type                     | Params
# ----------------------------------------------------------------
# 0 | _Code2Seq__metrics | MetricCollection         | 0
# 1 | _encoder           | PathEncoder              | 472 K
# 2 | _decoder           | Decoder                  | 384 K
# 3 | _Code2Seq__loss    | SequenceCrossEntropyLoss | 0
# ----------------------------------------------------------------
# 857 K     Trainable params
# 0         Non-trainable params
# 857 K     Total params
# 3.428     Total estimated model params size (MB)
# /Users/akihito/.local/share/virtualenvs/code2seq_pytorch-Ict_rOmF/lib/python3.8/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:617: UserWarning: Checkpoint directory /Users/akihito/Desktop/code2seq_pytorch/lightning_logs/version_54 exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# Validation sanity check: 0it [00:00, ?it/s]
#   0%|          | 0/1542 [00:00<?, ?it/s]
#   0%|          | 0/12117 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
