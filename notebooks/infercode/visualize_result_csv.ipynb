# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
RESULT_ROOT_PATH = "./results/result80epoch"

# %%
result_df = pd.read_csv(f"{RESULT_ROOT_PATH}/run-version_7-tag-val_bleu.csv");
result_df
# Out:
#        Wall time  Step  Value
# 0   1.645809e+09    47    0.0
# 1   1.645812e+09    95    0.0
# 2   1.645816e+09   143    0.0
# 3   1.645820e+09   191    0.0
# 4   1.645823e+09   239    0.0
# ..           ...   ...    ...
# 75  1.646055e+09  3647    0.0
# 76  1.646058e+09  3695    0.0
# 77  1.646061e+09  3743    0.0
# 78  1.646064e+09  3791    0.0
# 79  1.646067e+09  3839    0.0
#
# [80 rows x 3 columns]

# %%
result_df = pd.read_csv(f"{RESULT_ROOT_PATH}/run-version_7-tag-val_lei.csv")
result_df[result_df["Value"] != 0.0].min()
# Out:
# Wall time    1.645809e+09
# Step         4.700000e+01
# Value        9.319066e-01
# dtype: float64

# %%
def plot_2d_graph(path,label):
    df = pd.read_csv(path)
    x = list(range(len(df)))
    y = df["Value"].values
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set_xlabel("epoch_num")
    ax.set_ylabel(f"{label}")
    ax.plot(x,y)

# %%
labels = [["bleu","BLEU4"],["lei","Levenshtein"],["loss","Loss"]]
for label in labels:
    plot_2d_graph(f"{RESULT_ROOT_PATH}/run-version_7-tag-val_{label[0]}.csv",label[1])
